# %% [markdown]
# # 1. 데이터 수집하기
# ---

# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')
# Out:
# [nltk_data] Downloading package stopwords to /aiffel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data.sample(10)
# Out:
#                                                headlines  \
# 89019  Dwayne Johnson kisses Priyanka Chopra at Baywa...
# 60499  T'gana woman made to leave home for not making...
# 68498  Siemens sells Mumbai office property for Ã¢ÂÂ...
# 20155  We're not making progress on N Korea denuclear...
# 26793  Hardik 1st Indian to take 4 wickets, slam 30+ ...
# 80499  Abducted, raped 13-year-old wants to return to...
# 79174  CAG criticises Indian Railways over dirty line...
# 39415  Man bitten by head of severed snake that he ki...
# 87747  MIT study compares rivers on Mars, Earth, Satu...
# 14175  It was still around? User tweets on Google+ sh...
#
#                                                     text
# 89019  Actor Dwayne Johnson kissed his Baywatch co-st...
# 60499  A 25-year-old woman in Telangana's Warangal on...
# 68498  Engineering and technology firm Siemens on Mon...
# 20155  US President Donald Trump on Friday said that ...
# 26793  All-rounder Hardik Pandya became the first-eve...
# 80499  The 13-year-old Delhi girl who was raped after...
# 79174  The CAG has criticised Railways over improper ...
# 39415  A man in the US state of Texas required 26 dos...
# 87747  MIT Researchers studied three worlds in Solar ...
# 14175  Reacting to Google's announcement that it was ...

# %% [markdown]
# # 2. 데이터 전처리하기 (추상적 요약)
# ---
# 실습에서 사용된 전처리를 참고하여 각자 필요하다고 생각하는 전처리를 추가 사용하여 텍스트를 정규화 또는 정제해 보세요. 만약, 불용어 제거를 선택한다면 상대적으로 길이가 짧은 요약 데이터에 대해서도 불용어를 제거하는 것이 좋을지 고민해 보세요.

# %% [markdown]
# ## 2.1 중복 샘플과 NULL 값이 존재하는 샘플 제거

# %%
print('text 열에서 중복을 배제한 유일한 샘플의 수 :', data['text'].nunique())
print('headlines에서 중복을 배제한 유일한 샘플의 수', data['headlines'].nunique())
# Out:
# text 열에서 중복을 배제한 유일한 샘플의 수 : 98360
# headlines에서 중복을 배제한 유일한 샘플의 수 98280

# %%
# 중복 제거
data.drop_duplicates(subset=['text'], inplace=True)
print('전체 샘플 수 :', len(data))
# Out:
# 전체 샘플 수 : 98360

# %%
print(data.isnull().sum())
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %% [markdown]
# ## 2.2 텍스트 정규화와 불용어 제거

# %%
# 정규화 사전
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
# 불용어(일반적인 텍스트에는 자주 등장하지만 자연어 처리를 할 때 실질적으로 별 도움이 되지 않는 단어) 제거

print('불용어 개수 : ', len(stopwords.words('english')))
print(stopwords.words('english'))
# Out:
# 불용어 개수 :  179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# 데이터 전처리 함수
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
# 데이터 전처리 전,후 비교
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'

print(preprocess_sentence(temp_text))
print(preprocess_sentence(temp_summary, False))  # 불용어를 제거하지 않습니다.
# Out:
# everything bought great infact ordered twice third ordered wasfor mother father
# great way to start the day

# %%
import multiprocessing as mp   # 멀티 프로세싱으로 전처리 속도를 획기적으로 줄여봅시다
from multiprocessing import Pool
import numpy as np
import time
from functools import partial  # map을 할 때 함수에 여러 인자를 넣어줄 수 있도록 합니다

start = time.time()

# num_cores 만큼 쪼개진 데이터를 전처리하여 반환합니다
def appendTexts(sentences, remove_stopwords):
  texts = []
  for s in sentences:
    texts += preprocess_sentence(s, remove_stopwords),
  return texts

def preprocess_data(data, remove_stopwords=True):
  start_time = time.time()
  num_cores = mp.cpu_count()  # 컴퓨터의 코어 수를 구합니다

  text_data_split = np.array_split(data, num_cores)  # 코어 수만큼 데이터를 배분하여 병렬적으로 처리할 수 있게 합니다
  pool = Pool(num_cores)

  processed_data = np.concatenate(pool.map(partial(appendTexts, remove_stopwords=remove_stopwords), text_data_split))  # 각자 작업한 데이터를 하나로 합쳐줍니다
  pool.close()
  pool.join()
  print(time.time() - start_time, " seconds")
  return processed_data

clean_text=[]
clean_text = preprocess_data(data['text'])  # 클라우드 기준으로 3~4분 정도 소요 됩니다
print(clean_text)

clean_summary=[]
clean_summary = preprocess_data(data['headlines'], remove_stopwords=False) # 클라우드 기준 1분정도 소요됩니다.
print(clean_summary)
# Out:
# 184.85313081741333  seconds
# ['saurav kant alumnus upgrad iiit pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad degree career support helped transition data scientist tech mahindra salary hike upgrad online power learning powered lakh careers'
#  'kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit'
#  'new zealand defeated india wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy consecutive victories dating back march match witnessed india getting seventh lowest total odi cricket history'
#  ...
#  'according reports new version science fiction film matrix development michael jordan reportedly play lead role film screenwriter zak penn talks write script film reports added actor keanu reeves starred original film followed two sequels'
#  'new music video shows rapper snoop dogg aiming toy gun clown character parodying us president donald trump video also shows tv airing news conference headline ronald klump wants deport doggs airing live clown house video remixed version song lavender'
#  'madhesi morcha alliance seven political parties withdrawn support pm pushpa kamal dahal led nepal government failed meet seven day ultimatum fulfil demands including endorsement revised constitution amendment bill morcha seats parliament despite withdrawal support immediate threat government']
# 6.2746968269348145  seconds
# ['upgrad learner switches to career in ml al with salary hike'
#  'delhi techie wins free food from swiggy for one year on cred'
#  'new zealand end rohit sharma led india match winning streak' ...
#  'the matrix film to get reboot reports'
#  'snoop dogg aims gun at clown dressed as trump in new video'
#  'madhesi morcha withdraws support to nepalese government']

# %%
# 데이터 전처리 후 빈 샘플이 생겼는지 확인 후 제거
data['text'] = clean_text
data['headlines'] = clean_summary

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)

# %%
data.isnull().sum()
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플 수 : ', len(data))
# Out:
# 전체 샘플 수 :  98360

# %% [markdown]
# ## 2.3 샘플의 최대 길이 정하기
#
# Text와 Summary의 최소, 최대, 평균 길이를 구하고 또한 길이 분포를 시각화해서 볼게요.

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['text']]
summary_len = [len(s.split()) for s in data['headlines']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(summary_len)
plt.title('headlines')
plt.subplot(1,2,2)
plt.boxplot(text_len)
plt.title('text')
plt.tight_layout()
plt.show()

plt.title('headlines')
plt.hist(summary_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 60
# 텍스트의 평균 길이 : 35.09968483123221
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 16
# 요약의 평균 길이 : 9.299532330215534

# %%
text_max_len = 45
summary_max_len = 12

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s.split()) <= max_len):
            cnt = cnt + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율 : %s' %(max_len, (cnt/len(nested_list))))

# %%
below_threshold_len(text_max_len, data['text'])
below_threshold_len(summary_max_len, data['headlines'])
# Out:
# 전체 샘플 중 길이가 45 이하인 샘플의 비율 : 0.9967771451809678
# 전체 샘플 중 길이가 12 이하인 샘플의 비율 : 0.9880337535583571

# %%
data = data[data['text'].apply(lambda x:len(x.split()) <= text_max_len)]
data = data[data['headlines'].apply(lambda x:len(x.split()) <= summary_max_len)]

print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 96871

# %% [markdown]
# ## 2.4 시작 토큰과 종료 토큰 추가하기

# %%
# 요약데이터에는 시작 큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['headlines'].apply(lambda x : 'sostoken ' + x)
data['decoder_target'] = data['headlines'].apply(lambda x : x + ' eostoken')

data.head()
# Out:
#                                            headlines  \
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 5  rahat fateh ali khan denies getting notice for...
#
#                                                 text  \
# 0  saurav kant alumnus upgrad iiit pg program mac...
# 1  kunal shah credit card bill payment platform c...
# 2  new zealand defeated india wickets fourth odi ...
# 3  aegon life iterm insurance plan customers enjo...
# 5  pakistani singer rahat fateh ali khan denied r...
#
#                                        decoder_input  \
# 0  sostoken upgrad learner switches to career in ...
# 1  sostoken delhi techie wins free food from swig...
# 2  sostoken new zealand end rohit sharma led indi...
# 3  sostoken aegon life iterm insurance plan helps...
# 5  sostoken rahat fateh ali khan denies getting n...
#
#                                       decoder_target
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 5  rahat fateh ali khan denies getting notice for...

# %%
encoder_input = np.array(data['text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블

# %%
# 훈련 데이터와 테스트 데이터를 분리하는 방법은 분리 패키지를 사용하는 방법, 
# 또는 직접 코딩을 통해서 분리하는 방법 등 여러 가지 방법이 있을 텐데 여기서는 직접 해볼게요.

indicies = np.arange(encoder_input.shape[0])
np.random.shuffle(indicies)
print(indicies)
# Out:
# [18103 93819 28451 ... 69707 24207 79293]

# %%
encoder_input = encoder_input[indicies] 
decoder_input = decoder_input[indicies]
decoder_target = decoder_target[indicies]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 : ', n_of_val)
# Out:
# 테스트 데이터의 수 :  19374

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 77497
# 훈련 레이블의 개수 : 77497
# 테스트 데이터의 개수 : 19374
# 테스트 레이블의 개수 : 19374

# %% [markdown]
# ## 2-5 단어 집합(vocabulary) 만들기 및 정수 인코딩

# %%
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성

# %%
threshold = 5
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 trheshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value
    
    # 단어의 등장 빈도수가 threshold보다 작으면
    if value<threshold:
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value
        
print('단어 집합(vocabulary)의 크기 : ', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수 : %s' %(threshold-1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s' %(total_cnt-rare_cnt))
print('단어 집합에서 희귀 단어의 비율 : ', (rare_cnt/total_cnt)*100)
print('전체 등장 빈도에서 희귀 단어 등장 빈도 비율 : ', (rare_freq/total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 :  69199
# 등장 빈도가 4번 이하인 희귀 단어의 수 : 43056
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 26143
# 단어 집합에서 희귀 단어의 비율 :  62.220552320120234
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율 :  2.689875688031372

# %%
src_vocab = 6000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 6000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성.

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train)
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[80, 126, 2485, 2009, 1960, 2, 300, 1423, 32, 3482, 1297, 285, 18, 1347, 1347, 7, 103, 285, 397, 698, 24, 641, 999, 938, 124], [1879, 300, 1748, 1451, 1466, 50, 1347, 5228, 1227, 54, 30, 1451, 3255, 1347, 1329, 1778, 1601, 655, 2485, 1879, 30, 4, 34, 30, 42, 1879, 2289, 416, 1503, 1451, 971, 631, 246, 1052, 1373], [1093, 387, 181, 68, 980, 1306, 438, 2162, 2769, 94, 2365, 165, 145, 158, 399, 2148, 2162, 1037, 701, 920, 448, 30, 736, 5760, 5998, 802, 1127]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 29880
# 등장 빈도가 5번 이하인 희귀 단어의 수: 19512
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 10368
# 단어 집합에서 희귀 단어의 비율: 65.3012048192771
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 4.700254475983357

# %%
tar_vocab = 5000
tar_tokenizer = Tokenizer(num_words=tar_vocab)
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 1841, 1342, 152, 50, 4, 1532, 153, 11, 1483], [1, 851, 1644, 53, 6, 145, 1292, 572, 59], [1, 818, 88, 424, 19, 1167, 3372], [1, 185, 2329, 2630, 2048, 3, 34, 1136, 501], [1, 1258, 77, 714, 1665, 181, 3, 244, 1686, 3736, 38]]
# target
# decoder  [[1841, 1342, 152, 50, 4, 1532, 153, 11, 1483, 2], [851, 1644, 53, 6, 145, 1292, 572, 59, 2], [818, 88, 424, 19, 1167, 3372, 2], [185, 2329, 2630, 2048, 3, 34, 1136, 501, 2], [1258, 77, 714, 1665, 181, 3, 244, 1686, 3736, 38, 2]]

# %% [markdown]
# ## 2-6 빈도수가 낮은 단어 삭제 후 빈 샘플 제거

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = np.delete(encoder_input_train, drop_train, axis=0)
decoder_input_train = np.delete(decoder_input_train, drop_train, axis=0)
decoder_target_train = np.delete(decoder_target_train, drop_train, axis=0)

encoder_input_test = np.delete(encoder_input_test, drop_test, axis=0)
decoder_input_test = np.delete(decoder_input_test, drop_test, axis=0)
decoder_target_test = np.delete(decoder_target_test, drop_test, axis=0)

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 1
# 삭제할 테스트 데이터의 개수 : 1
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# 훈련 데이터의 개수 : 77496
# 훈련 레이블의 개수 : 77496
# 테스트 데이터의 개수 : 19373
# 테스트 레이블의 개수 : 19373

# %% [markdown]
# ## 2-7 패딩하기

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')

# %% [markdown]
# # 3. 어텐션 메커니즘 사용하기 (추상적 요약)
# ---
# 일반적인 seq2seq보다는 어텐션 메커니즘을 사용한 seq2seq를 사용하는 것이 더 나은 성능을 얻을 수 있어요. 실습 내용을 참고하여 어텐션 메커니즘을 사용한 seq2seq를 설계해 보세요.

# %% [markdown]
# ## 3-1 일반적인 seq2seq 모델

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 45)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 45, 128)      768000      input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 45, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 45, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    640000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 45, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 5000)   1285000     lstm_3[0][0]
# ==================================================================================================
# Total params: 4,532,104
# Trainable params: 4,532,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3-2 어텐션 매커니즘

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/thushv89/attention_keras/master/src/layers/attention.py", filename="attention.py")
from attention import AttentionLayer

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hideen state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 45)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 45, 128)      768000      input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 45, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 45, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    640000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 45, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 256),  131328      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 5000)   2565000     concat_layer[0][0]
# ==================================================================================================
# Total params: 5,943,432
# Trainable params: 5,943,432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3-3 모델 훈련하기

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
                   validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
                   batch_size=512, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 152/152 [==============================] - 159s 967ms/step - loss: 5.5504 - val_loss: 4.7980
# Epoch 2/50
# 152/152 [==============================] - 147s 970ms/step - loss: 4.7230 - val_loss: 4.4686
# Epoch 3/50
# 152/152 [==============================] - 147s 967ms/step - loss: 4.4078 - val_loss: 4.2275
# Epoch 4/50
# 152/152 [==============================] - 146s 963ms/step - loss: 4.1645 - val_loss: 4.0463
# Epoch 5/50
# 152/152 [==============================] - 146s 961ms/step - loss: 3.9602 - val_loss: 3.8975
# Epoch 6/50
# 152/152 [==============================] - 145s 956ms/step - loss: 3.7841 - val_loss: 3.7726
# Epoch 7/50
# 152/152 [==============================] - 145s 952ms/step - loss: 3.6409 - val_loss: 3.6555
# Epoch 8/50
# 152/152 [==============================] - 144s 950ms/step - loss: 3.5081 - val_loss: 3.5826
# Epoch 9/50
# 152/152 [==============================] - 145s 952ms/step - loss: 3.3981 - val_loss: 3.5073
# Epoch 10/50
# 152/152 [==============================] - 145s 952ms/step - loss: 3.2983 - val_loss: 3.4540
# Epoch 11/50
# 152/152 [==============================] - 145s 952ms/step - loss: 3.2138 - val_loss: 3.4068
# Epoch 12/50
# 152/152 [==============================] - 144s 951ms/step - loss: 3.1328 - val_loss: 3.3655
# Epoch 13/50
# 152/152 [==============================] - 144s 950ms/step - loss: 3.0602 - val_loss: 3.3250
# Epoch 14/50
# 152/152 [==============================] - 144s 950ms/step - loss: 2.9969 - val_loss: 3.2900
# Epoch 15/50
# 152/152 [==============================] - 145s 951ms/step - loss: 2.9390 - val_loss: 3.2695
# Epoch 16/50
# 152/152 [==============================] - 145s 954ms/step - loss: 2.8872 - val_loss: 3.2554
# Epoch 17/50
# 152/152 [==============================] - 145s 953ms/step - loss: 2.8350 - val_loss: 3.2252
# Epoch 18/50
# 152/152 [==============================] - 144s 950ms/step - loss: 2.7816 - val_loss: 3.2049
# Epoch 19/50
# 152/152 [==============================] - 145s 952ms/step - loss: 2.7355 - val_loss: 3.1978
# Epoch 20/50
# 152/152 [==============================] - 145s 952ms/step - loss: 2.6891 - val_loss: 3.1770
# Epoch 21/50
# 152/152 [==============================] - 144s 949ms/step - loss: 2.6483 - val_loss: 3.1701
# Epoch 22/50
# 152/152 [==============================] - 144s 951ms/step - loss: 2.6121 - val_loss: 3.1604
# Epoch 23/50
# 152/152 [==============================] - 145s 953ms/step - loss: 2.5775 - val_loss: 3.1537
# Epoch 24/50
# 152/152 [==============================] - 145s 952ms/step - loss: 2.5403 - val_loss: 3.1501
# Epoch 25/50
# 152/152 [==============================] - 144s 951ms/step - loss: 2.5072 - val_loss: 3.1350
# Epoch 26/50
# 152/152 [==============================] - 144s 949ms/step - loss: 2.4775 - val_loss: 3.1316
# Epoch 27/50
# 152/152 [==============================] - 145s 952ms/step - loss: 2.4437 - val_loss: 3.1312
# Epoch 28/50
# 152/152 [==============================] - 144s 951ms/step - loss: 2.4153 - val_loss: 3.1201
# Epoch 29/50
# 152/152 [==============================] - 145s 953ms/step - loss: 2.3841 - val_loss: 3.1253
# Epoch 30/50
# 152/152 [==============================] - 145s 953ms/step - loss: 2.3605 - val_loss: 3.1180
# Epoch 31/50
# 152/152 [==============================] - 145s 952ms/step - loss: 2.3337 - val_loss: 3.1161
# Epoch 32/50
# 152/152 [==============================] - 145s 953ms/step - loss: 2.3091 - val_loss: 3.1175
# Epoch 33/50
# 152/152 [==============================] - 145s 954ms/step - loss: 2.2840 - val_loss: 3.1174
# Epoch 00033: early stopping

# %% [markdown]
# 위 코드에서는 val_loss(검증 데이터의 손실)을 관찰하다가, 검증 데이터의 손실이 줄어들지 않고 증가하는 현상이 2회(patience=2) 관측되면 학습을 멈추도록 설정돼 있어요. EarlyStopping이 작동한다면 epochs가 아무리 크게 설정되어 있어도 모델 훈련을 최적점에서 멈출 수 있겠네요.

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# # 4. 실제 결과와 요약문 비교하기 (추상적 요약)
# ---
# 원래의 요약문(headlines 열)과 학습을 통해 얻은 추상적 요약의 결과를 비교해 보세요.
# 테스트 단계에서는 정수 인덱스 행렬로 존재하던 텍스트 데이터를 실제 데이터로 복원해야 하므로, 필요한 3개의 사전을 아래와 같이 미리 준비해 둡니다.

# %% [markdown]
# ## 4.1 인퍼런스 모델 구현

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수->단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어->정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수->단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용.
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat)

# 최종 디코더 모델
decoder_model = Model(
            [decoder_inputs] + [decoder_hidden_state_input, decoder_state_input_h, decoder_state_input_c],
            [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %% [markdown]
# ## 4-2 모델 테스트

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if i!=0:
            temp=temp+src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if ((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : german city least world indian cities ranked according survey indian cities bengaluru kolkata mumbai delhi notably four german cities feature list top
# 실제 요약 : german cities least indian ranked over survey
# 예측 요약 :  german city named world best cities
#
#
# 원문 : official twitter account icc used picture prince harry meghan markle royal wedding reaction rcb ab de villiers one handed catch icc placed picture wherein prince harry seen markle appears next picture de villiers taking catch
# 실제 요약 : icc uses royal couple pic as reaction to abd catch
# 예측 요약 :  markle shares pic with dhoni daughter in brazil
#
#
# 원문 : absconding liquor baron vijay mallya commenting appearance london court despite appearing judge last hearing said lawyers responding reporters regard new charges mallya said present whatever want respond notably mallya owes crore banks
# 실제 요약 : do as my lawyers says vijay mallya
# 예측 요약 :  no question of judge in london case mallya
#
#
# 원문 : andhra pradesh government entered understanding national university singapore various governance work knowledge practices governance public administration independent audit real time monitoring system key performance master plan ease business
# 실제 요약 : andhra govt varsity sign to improve
# 예측 요약 :  andhra pradesh to get data with
#
#
# 원문 : fresh plea filed supreme court friday seeking extension ban sale firecrackers delhi ncr beyond october petitioner arjun gopal said ban extended view pollution levels region bench comprising several said consider whether plea heard
# 실제 요약 : plea filed in sc for ban in delhi ncr
# 예측 요약 :  sc stays ban on firecrackers sale of firecrackers
#
#
# 원문 : statue lady justice removed recently outside supreme court bangladesh capital different location court grounds would less visible statue installed december last year removed following months protests religious groups deemed un islamic
# 실제 요약 : un islamic lady justice statue in bangladesh
# 예측 요약 :  ban on sc judge in tamil nadu
#
#
# 원문 : iran supreme leader warned iraqi pm al country trust us fight isis unity important gains terrorists trust america harm told al iraq one countries us iran
# 실제 요약 : iran supreme leader warns iraq not to trust us
# 예측 요약 :  us has no of war against us iran
#
#
# 원문 : kkr captain dinesh karthik called year old gill player world cup guy team girls around boys karthik added introducing gill post match interview interview gill revealed wants like karthik
# 실제 요약 : girls around him some boys karthik on
# 예측 요약 :  karthik was not enough for world cup final karthik
#
#
# 원문 : competition commission india wednesday imposed fine crore jet airways indigo spicejet alleged regulator said airlines acted manner fix fuel cargo transport jet airways fined crore penalties indigo spicejet crore crore respectively
# 실제 요약 : jet airways indigo spicejet fined crore for unfair biz
# 예측 요약 :  spicejet spicejet jet airways jet airways flights
#
#
# 원문 : railways ministry wednesday informed rajya sabha human error reason behind train accidents year error led accidents accidents occurred due reason one accident occurred due
# 실제 요약 : human error reason behind train accidents govt
# 예측 요약 :  railways to train to save
#
#
# 원문 : according reports ali part comedian sunil grover new comedy show reportedly replace abhishek show drama company reports added sunil already begun ali sunil earlier part kapil sharma show
# 실제 요약 : ali to be part of sunil new comedy show reports
# 예측 요약 :  to feature in sunil grover
#
#
# 원문 : recently got married girlfriend actress ekta jammu september year said see think one ekta pretty person besides drop dead like complete package added talking wife
# 실제 요약 : am what did ekta see in me on his wife
# 예측 요약 :  denies rumours of her girlfriend
#
#
# 원문 : bjp tuesday expelled one candidates upcoming municipal corporation delhi elections sex scandal accused former aap minister spotted sandeep kumar scheduled caste scheduled welfare women child welfare minister delhi government expelled cabinet scandal
# 실제 요약 : bjp candidate sacked after aap mla for her
# 예측 요약 :  bjp expels for dalit sex in delhi
#
#
# 원문 : williams portrays game thrones said really proud final season always felt say things like really proud work put know anyone going one wants end right time added
# 실제 요약 : felt to say really proud of got final season
# 예측 요약 :  got one time in my life says dhawan on his th
#
#
# 원문 : amid agency two top ranked officials bjp spokesperson monday said people maintain faith central bureau investigation asked cbi filing fir special director rakesh asthana bribery case said also report cbi chief alok verma
# 실제 요약 : people should maintain their faith in the cbi bjp
# 예측 요약 :  cbi probe against cbi in probe on cbi probe
#
#
# 원문 : six members family including parents four daughters two married found dead house karnataka saturday police said father children allegedly wife four daughters neighbours said family unable pay loans due failed
# 실제 요약 : members of family found dead at their house in karnataka
# 예측 요약 :  family of family found dead in uttar pradesh
#
#
# 원문 : many initial public hit indian stock market year raising billion according report report said represents increase deal numbers compared notably largest ipo region general insurance corporation india worth billion
# 실제 요약 : firms raised billion through in report
# 예측 요약 :  india has most valued in the world bank
#
#
# 원문 : release date arjun kapoor parineeti chopra starrer sandeep aur postponed august march arjun play policeman parineeti playing corporate worker film sandeep aur directed banerjee earlier directed love sex aur
# 실제 요약 : release date of aur postponed
# 예측 요약 :  release date of parineeti arjun starrer veere di out
#
#
# 원문 : many inmates far around prisoners escaped mass prison indonesia island friday according officials inmates told police escaped due conditions prison notably jail capacity housing nearly inmates
# 실제 요약 : indonesia inmates who broke out of prison
# 예측 요약 :  inmates inmates escape from prison in prison
#
#
# 원문 : world number serena williams defeated world number thursday enter ninth us open final years maiden final serena played grand slam finals till winning year old american face year old japan final saturday
# 실제 요약 : serena enters her th us open final yrs after her first
# 예측 요약 :  world no serena to reach world no slam final
#
#
# 원문 : former australian captain steve said previous lack ball tampering resulted things getting control ball tampering scandal took place cape town earlier year shame got point authorities let happen added
# 실제 요약 : authorities let aus ball tampering scandal happen steve
# 예측 요약 :  ball tampering scandal steve smith
#
#
# 원문 : nawazuddin siddiqui speaking understanding thackeray character said think anger considering situation society went time time maharashtra shut youth suddenly faced creating jobs responsibility government happen nawazuddin added
# 실제 요약 : thackeray anger and were nawazuddin
# 예측 요약 :  nawazuddin is not to fight smoking in film nawazuddin
#
#
# 원문 : supreme court sunday rejected petition filed bengaluru based woman claiming biological daughter former tamil nadu chief minister jayalalithaa dna test ascertain apex court dismissed plea saying cannot article indian constitution reports said
# 실제 요약 : sc rejects dna test for woman claiming to be jaya daughter
# 예측 요약 :  sc rejects plea to woman wedding in law
#
#
# 원문 : year old american request free chicken year fast food chain lakh times making popular tweet tweeted yo many year free chicken following replied million began
# 실제 요약 : plea for free chicken most popular tweet of
# 예측 요약 :  uk teen offers to hire for food
#
#
# 원문 : pm narendra modi saturday attended ceremony maldives new president ibrahim mohamed island nation capital india maldives share strong partnership history government vision development neighbours pm modi wrote facebook post ahead ceremony
# 실제 요약 : pm modi attends in ceremony of new maldives president
# 예측 요약 :  pm modi pays tribute to maldives prez
#
#
# 원문 : pizza measuring feet set guinness world record longest pizza world pizza estimated kg special temperature record set california united states event believed table holding pizza also record breaking
# 실제 요약 : over foot pizza breaks record for world longest
# 예측 요약 :  world oldest floating swimming pool in world record
#
#
# 원문 : indian premier league council hiked salary cap ipl crore season crore last year allowed spend crore crore teams need spend least salary cap season
# 실제 요약 : salary cap for ipl teams hiked from crore to crore
# 예측 요약 :  how much money to earn cr in ipl auction
#
#
# 원문 : producer kiran shroff talking comments faced said central board film certification member asked could make film like woman male member added woman look wearing kiran said thoughts
# 실제 요약 : cbfc member made sexist remark maker
# 예측 요약 :  slams rumours of being called
#
#
# 원문 : stopping deliveries day due suspension rail services mumbai tuesday fed people weak affected heavy rainfall city act carried bank initiative launched last year aim fight hunger
# 실제 요약 : feed poor people affected by mumbai rains
# 예측 요약 :  what are the of the green
#
#
# 원문 : rape convict ram rahim singh running based dera sacha sauda haryana jail currently lodged dera chairperson said tuesday adding plans naming refuted claims made ram rahim mother son nominated next dera chief
# 실제 요약 : ram rahim singh to run dera from jail
# 예측 요약 :  ram rahim dera ram rahim singh
#
#
# 원문 : following chennai super kings record third title indian premier league csk captain ms dhoni said team visiting chennai meet franchise fans plans celebrate get together hotel celebrate dhoni added asked celebrations
# 실제 요약 : going to chennai to celebrate ipl title win with fans dhoni
# 예측 요약 :  dhoni posts final with dhoni in ipl
#
#
# 원문 : woman allegedly abducted golf course metro station noida gang raped moving vehicle thrown near temple delhi friday police registered fir unidentified men sent victim medical examination woman reportedly waiting cab near station abducted
# 실제 요약 : woman abducted gang raped in moving car in noida
# 예측 요약 :  woman gangraped by men gangraped in moving train in bihar
#
#
# 원문 : delhi cm arvind kejriwal friday tweeted approved delivery proposal comes days supreme court ruled delhi government require lieutenant governor every issue act earlier aap government claimed anil baijal rejected scheme
# 실제 요약 : approved delivery kejriwal after sc verdict
# 예측 요약 :  delhi cm kejriwal to make quota in delhi
#
#
# 원문 : air india issued advisory asking cabin crew members carry uniform documents holiday report duty falls short staff destination advisory comes air india flying minimum crew members per directorate general civil aviation norms
# 실제 요약 : air india asks crew to carry uniform on holiday
# 예측 요약 :  air india denies delay in air india crew crew
#
#
# 원문 : armed forces personnel may soon wear according reports defence ministry sent uniform along samples villages industries commission minister state defence subhash said friday requested armed forces consider using security personnel added
# 실제 요약 : armed forces may soon wear uniform
# 예측 요약 :  terrorists to observe armed forces in mizoram
#
#
# 원문 : startups enterprises offering shared private offices conference rooms networking opportunities help business grow first delhi ncr location launch early located right next metro station making easily
# 실제 요약 : wework to open in delhi ncr
# 예측 요약 :  invests in bengaluru to be launched
#
#
# 원문 : govinda responded late actor khan son criticism wherein questioned govinda call even demise kid like comment got know said govinda criticised govinda called father figure instagram demise
# 실제 요약 : he is kid govinda on son criticism after actor death
# 예측 요약 :  dad is my son govinda on son death
#
#
# 원문 : tata motors land rover warned bad brexit deal could lead thousands job losses cost company billion year losing easy access europe single market would mean customs official becomes important engineer ceo said
# 실제 요약 : tata jaguar warns hard brexit could cost thousands of jobs
# 예측 요약 :  tata steel could not impact steel steel steel steel
#
#
# 원문 : india biggest sale flipkart big billion days back september th th event finally bring solution biggest indian across flipkart set offer tonnes exclusive deals consumers days
# 실제 요약 : flipkart big billion days starts from september th
# 예측 요약 :  india has billion in last years
#
#
# 원문 : barcelona midfielder currently loan ak banned record matches pushing insulting threatening turkish league match year old sent assistant referee decision also handed lakh fine thrown direction
# 실제 요약 : bar handed record match ban for
# 예측 요약 :  iranian footballer banned from iran for
#
#
# 원문 : nasa discovered planet known universe surface temperature jupiter like giant nearly hot sun locked host star meaning planet one side always facing star researchers said host star even planet
# 실제 요약 : hottest ever known planet found with of
# 예측 요약 :  nasa finds image of earth like star found in orbit
#
#
# 원문 : cbi booked auto jharkhand allegedly loan amount causing loss crore corporation bank agency booked estate directors along bank sanjay kumar corporation bank alleged kumar filed valuation reports based loan sanctioned
# 실제 요약 : bank reports fraud of crore to cbi
# 예측 요약 :  cbi books booked for crore fraud in bank fraud
#
#
# 원문 : india japan signed pact thursday start service help japanese people living india order food japan saying japan become third largest investor india pm narendra modi added food delivery service called cool box service help improve people people ties two countries
# 실제 요약 : service to order food from japan to india announced
# 예측 요약 :  japan to build world largest branch with japan
#
#
# 원문 : delhi transport minister kailash said state government may implement even vehicle scheme view increasing pollution levels wednesday wrote delhi transport corporation ministry officials asking fully implementation scheme announced
# 실제 요약 : delhi govt may implement odd even scheme again minister
# 예측 요약 :  delhi govt to adopt odd even in odd even
#
#
# 원문 : people bihar occasion bihar pm narendra modi thursday tweeted right historical times bihar contribution towards nation progress bihar observed mark formation state bihar bengal presidency british
# 실제 요약 : bihar to india pm modi
# 예측 요약 :  modi has not in gujarat gujarat cm
#
#
# 원문 : rajasthan high court directed makers padmaavat screen film court january response plea director sanjay leela bhansali appealed fir state fir filed march sought action bhansali deepika padukone ranveer singh
# 실제 요약 : screen padmaavat for court before jan rajasthan hc
# 예측 요약 :  court asks baahubali to release padmaavat in raj
#
#
# 원문 : benchmark index sensex fell second consecutive session friday dragged reliance industries hdfc yes bank sensex closed points nifty index ended points lower non banking finance companies continued face selling pressure housing finance falling
# 실제 요약 : sensex falls for second straight day points
# 예측 요약 :  sensex jumps points points to points in months
#
#
# 원문 : former pakistan president claimed chief hafiz saeed involved mumbai attacks left dead hafiz saeed issue issue india united states pakistan call terrorist added notably us declared international terrorist organisation
# 실제 요약 : hafiz saeed not involved in mumbai attacks musharraf
# 예측 요약 :  mastermind hafiz saeed is mastermind hafiz saeed
#
#
# 원문 : least flights major offices stock markets opened hour late students took nine hour college entrance exam south korea thursday south korean airports suspended minutes english test students stuck traffic rushed police vehicles exam centres
# 실제 요약 : flights suspended offices open late for hour exam in korea
# 예측 요약 :  paris student who missed alcohol from us
#
#
# 원문 : pakistan opposition parties nominated former pm nawaz sharif brother sharif pm candidate comes pakistan single largest party recently held general elections nominated imran khan pm candidate pakistan claimed support members form government
# 실제 요약 : pak opp fields sharif as pm against imran
# 예측 요약 :  pakistan pm nawaz sharif elected pm nawaz sharif

# %% [markdown]
# # Step 5. Summa을 이용해서 추출적 요약해보기
# ---
# 추상적 요약은 추출적 요약과는 달리 문장의 표현력을 다양하게 가져갈 수 있지만, 추출적 요약에 비해서 난이도가 높아요. 반대로 말하면 추출적 요약은 추상적 요약에 비해 난이도가 낮고 기존 문장에서 문장을 꺼내오는 것이므로 잘못된 요약이 나올 가능성이 낮아요.
#
# Summa의 summarize를 사용하여 추출적 요약을 해보세요.

# %% [markdown]
# * text (str) : 요약할 테스트.
# * ratio (float, optional) – 요약문에서 원본에서 선택되는 문장 비율. 0~1 사이값
# * words (int or None, optional) – 출력에 포함할 단어 수. 만약, ratio와 함께 두 파라미터가 모두 제공되는 경우 ratio는 무시한다.
# * split (bool, optional) – True면 문장 list / False는 조인(join)된 문자열을 반환

# %%
from summa.summarizer import summarize

for i in range(50,200): 
    print("원문 :", seq2text(encoder_input_test[i])) 
    print("\n") 
    print("실제 요약 :", seq2summary(decoder_input_test[i])) 
    print("\n") 
    print("추상적 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len))) 
    
    dot = 0 
    tmptxt = [] 
    for j in seq2text(encoder_input_test[i]).split() : 
        tmptxt.append(j) 
        dot += 1 
        if dot % 10 == 9: 
            tmptxt.append(".")
    print("\n") 
    print("추출적 요약:", summarize(' '.join(tmptxt), ratio=0.5))
    print('-'*100)
# Out:
# 원문 : german city least world indian cities ranked according survey indian cities bengaluru kolkata mumbai delhi notably four german cities feature list top
#
#
# 실제 요약 : german cities least indian ranked over survey
#
#
# 추상적 요약 :  german city named world best cities
#
#
# 추출적 요약: german city least world indian cities ranked according survey .
# ----------------------------------------------------------------------------------------------------
# 원문 : official twitter account icc used picture prince harry meghan markle royal wedding reaction rcb ab de villiers one handed catch icc placed picture wherein prince harry seen markle appears next picture de villiers taking catch
#
#
# 실제 요약 : icc uses royal couple pic as reaction to abd catch
#
#
# 추상적 요약 :  markle shares pic with dhoni daughter in brazil
#
#
# 추출적 요약: official twitter account icc used picture prince harry meghan .
# catch icc placed picture wherein prince harry seen markle appears .
# ----------------------------------------------------------------------------------------------------
# 원문 : absconding liquor baron vijay mallya commenting appearance london court despite appearing judge last hearing said lawyers responding reporters regard new charges mallya said present whatever want respond notably mallya owes crore banks
#
#
# 실제 요약 : do as my lawyers says vijay mallya
#
#
# 추상적 요약 :  no question of judge in london case mallya
#
#
# 추출적 요약: absconding liquor baron vijay mallya commenting appearance london court .
# despite appearing judge last hearing said lawyers responding reporters regard .
# ----------------------------------------------------------------------------------------------------
# 원문 : andhra pradesh government entered understanding national university singapore various governance work knowledge practices governance public administration independent audit real time monitoring system key performance master plan ease business
#
#
# 실제 요약 : andhra govt varsity sign to improve
#
#
# 추상적 요약 :  andhra pradesh to get data with
#
#
# 추출적 요약: andhra pradesh government entered understanding national university singapore various .
# ----------------------------------------------------------------------------------------------------
# 원문 : fresh plea filed supreme court friday seeking extension ban sale firecrackers delhi ncr beyond october petitioner arjun gopal said ban extended view pollution levels region bench comprising several said consider whether plea heard
#
#
# 실제 요약 : plea filed in sc for ban in delhi ncr
#
#
# 추상적 요약 :  sc stays ban on firecrackers sale of firecrackers
#
#
# 추출적 요약: fresh plea filed supreme court friday seeking extension ban .
# ban extended view pollution levels region bench comprising several said .
# ----------------------------------------------------------------------------------------------------
# 원문 : statue lady justice removed recently outside supreme court bangladesh capital different location court grounds would less visible statue installed december last year removed following months protests religious groups deemed un islamic
#
#
# 실제 요약 : un islamic lady justice statue in bangladesh
#
#
# 추상적 요약 :  ban on sc judge in tamil nadu
#
#
# 추출적 요약: statue lady justice removed recently outside supreme court bangladesh .
# capital different location court grounds would less visible statue installed .
# ----------------------------------------------------------------------------------------------------
# 원문 : iran supreme leader warned iraqi pm al country trust us fight isis unity important gains terrorists trust america harm told al iraq one countries us iran
#
#
# 실제 요약 : iran supreme leader warns iraq not to trust us
#
#
# 추상적 요약 :  us has no of war against us iran
#
#
# 추출적 요약: iran supreme leader warned iraqi pm al country trust .
# ----------------------------------------------------------------------------------------------------
# 원문 : kkr captain dinesh karthik called year old gill player world cup guy team girls around boys karthik added introducing gill post match interview interview gill revealed wants like karthik
#
#
# 실제 요약 : girls around him some boys karthik on
#
#
# 추상적 요약 :  karthik was not enough for world cup final karthik
#
#
# 추출적 요약: kkr captain dinesh karthik called year old gill player .
# ----------------------------------------------------------------------------------------------------
# 원문 : competition commission india wednesday imposed fine crore jet airways indigo spicejet alleged regulator said airlines acted manner fix fuel cargo transport jet airways fined crore penalties indigo spicejet crore crore respectively
#
#
# 실제 요약 : jet airways indigo spicejet fined crore for unfair biz
#
#
# 추상적 요약 :  spicejet spicejet jet airways jet airways flights
#
#
# 추출적 요약: competition commission india wednesday imposed fine crore jet airways .
# cargo transport jet airways fined crore penalties indigo spicejet crore .
# ----------------------------------------------------------------------------------------------------
# 원문 : railways ministry wednesday informed rajya sabha human error reason behind train accidents year error led accidents accidents occurred due reason one accident occurred due
#
#
# 실제 요약 : human error reason behind train accidents govt
#
#
# 추상적 요약 :  railways to train to save
#
#
# 추출적 요약: reason one accident occurred due
# ----------------------------------------------------------------------------------------------------
# 원문 : according reports ali part comedian sunil grover new comedy show reportedly replace abhishek show drama company reports added sunil already begun ali sunil earlier part kapil sharma show
#
#
# 실제 요약 : ali to be part of sunil new comedy show reports
#
#
# 추상적 요약 :  to feature in sunil grover
#
#
# 추출적 요약: according reports ali part comedian sunil grover new comedy .
# ----------------------------------------------------------------------------------------------------
# 원문 : recently got married girlfriend actress ekta jammu september year said see think one ekta pretty person besides drop dead like complete package added talking wife
#
#
# 실제 요약 : am what did ekta see in me on his wife
#
#
# 추상적 요약 :  denies rumours of her girlfriend
#
#
# 추출적 요약: recently got married girlfriend actress ekta jammu september year .
# ----------------------------------------------------------------------------------------------------
# 원문 : bjp tuesday expelled one candidates upcoming municipal corporation delhi elections sex scandal accused former aap minister spotted sandeep kumar scheduled caste scheduled welfare women child welfare minister delhi government expelled cabinet scandal
#
#
# 실제 요약 : bjp candidate sacked after aap mla for her
#
#
# 추상적 요약 :  bjp expels for dalit sex in delhi
#
#
# 추출적 요약: bjp tuesday expelled one candidates upcoming municipal corporation delhi .
# expelled cabinet scandal
# ----------------------------------------------------------------------------------------------------
# 원문 : williams portrays game thrones said really proud final season always felt say things like really proud work put know anyone going one wants end right time added
#
#
# 실제 요약 : felt to say really proud of got final season
#
#
# 추상적 요약 :  got one time in my life says dhawan on his th
#
#
# 추출적 요약: williams portrays game thrones said really proud final season .
# ----------------------------------------------------------------------------------------------------
# 원문 : amid agency two top ranked officials bjp spokesperson monday said people maintain faith central bureau investigation asked cbi filing fir special director rakesh asthana bribery case said also report cbi chief alok verma
#
#
# 실제 요약 : people should maintain their faith in the cbi bjp
#
#
# 추상적 요약 :  cbi probe against cbi in probe on cbi probe
#
#
# 추출적 요약: said people maintain faith central bureau investigation asked cbi filing .
# cbi chief alok verma
# ----------------------------------------------------------------------------------------------------
# 원문 : six members family including parents four daughters two married found dead house karnataka saturday police said father children allegedly wife four daughters neighbours said family unable pay loans due failed
#
#
# 실제 요약 : members of family found dead at their house in karnataka
#
#
# 추상적 요약 :  family of family found dead in uttar pradesh
#
#
# 추출적 요약: six members family including parents four daughters two married .
# wife four daughters neighbours said family unable pay loans due .
# ----------------------------------------------------------------------------------------------------
# 원문 : many initial public hit indian stock market year raising billion according report report said represents increase deal numbers compared notably largest ipo region general insurance corporation india worth billion
#
#
# 실제 요약 : firms raised billion through in report
#
#
# 추상적 요약 :  india has most valued in the world bank
#
#
# 추출적 요약: billion according report report said represents increase deal numbers compared .
# ----------------------------------------------------------------------------------------------------
# 원문 : release date arjun kapoor parineeti chopra starrer sandeep aur postponed august march arjun play policeman parineeti playing corporate worker film sandeep aur directed banerjee earlier directed love sex aur
#
#
# 실제 요약 : release date of aur postponed
#
#
# 추상적 요약 :  release date of parineeti arjun starrer veere di out
#
#
# 추출적 요약: release date arjun kapoor parineeti chopra starrer sandeep aur .
# ----------------------------------------------------------------------------------------------------
# 원문 : many inmates far around prisoners escaped mass prison indonesia island friday according officials inmates told police escaped due conditions prison notably jail capacity housing nearly inmates
#
#
# 실제 요약 : indonesia inmates who broke out of prison
#
#
# 추상적 요약 :  inmates inmates escape from prison in prison
#
#
# 추출적 요약: many inmates far around prisoners escaped mass prison indonesia .
# ----------------------------------------------------------------------------------------------------
# 원문 : world number serena williams defeated world number thursday enter ninth us open final years maiden final serena played grand slam finals till winning year old american face year old japan final saturday
#
#
# 실제 요약 : serena enters her th us open final yrs after her first
#
#
# 추상적 요약 :  world no serena to reach world no slam final
#
#
# 추출적 요약: ninth us open final years maiden final serena played grand .
# slam finals till winning year old american face year old .
# ----------------------------------------------------------------------------------------------------
# 원문 : former australian captain steve said previous lack ball tampering resulted things getting control ball tampering scandal took place cape town earlier year shame got point authorities let happen added
#
#
# 실제 요약 : authorities let aus ball tampering scandal happen steve
#
#
# 추상적 요약 :  ball tampering scandal steve smith
#
#
# 추출적 요약: former australian captain steve said previous lack ball tampering .
# ----------------------------------------------------------------------------------------------------
# 원문 : nawazuddin siddiqui speaking understanding thackeray character said think anger considering situation society went time time maharashtra shut youth suddenly faced creating jobs responsibility government happen nawazuddin added
#
#
# 실제 요약 : thackeray anger and were nawazuddin
#
#
# 추상적 요약 :  nawazuddin is not to fight smoking in film nawazuddin
#
#
# 추출적 요약: nawazuddin siddiqui speaking understanding thackeray character said think anger .
# ----------------------------------------------------------------------------------------------------
# 원문 : supreme court sunday rejected petition filed bengaluru based woman claiming biological daughter former tamil nadu chief minister jayalalithaa dna test ascertain apex court dismissed plea saying cannot article indian constitution reports said
#
#
# 실제 요약 : sc rejects dna test for woman claiming to be jaya daughter
#
#
# 추상적 요약 :  sc rejects plea to woman wedding in law
#
#
# 추출적 요약: supreme court sunday rejected petition filed bengaluru based woman .
# test ascertain apex court dismissed plea saying cannot article indian .
# ----------------------------------------------------------------------------------------------------
# 원문 : year old american request free chicken year fast food chain lakh times making popular tweet tweeted yo many year free chicken following replied million began
#
#
# 실제 요약 : plea for free chicken most popular tweet of
#
#
# 추상적 요약 :  uk teen offers to hire for food
#
#
# 추출적 요약: year old american request free chicken year fast food .
# ----------------------------------------------------------------------------------------------------
# 원문 : pm narendra modi saturday attended ceremony maldives new president ibrahim mohamed island nation capital india maldives share strong partnership history government vision development neighbours pm modi wrote facebook post ahead ceremony
#
#
# 실제 요약 : pm modi attends in ceremony of new maldives president
#
#
# 추상적 요약 :  pm modi pays tribute to maldives prez
#
#
# 추출적 요약: pm narendra modi saturday attended ceremony maldives new president .
# history government vision development neighbours pm modi wrote facebook post .
# ----------------------------------------------------------------------------------------------------
# 원문 : pizza measuring feet set guinness world record longest pizza world pizza estimated kg special temperature record set california united states event believed table holding pizza also record breaking
#
#
# 실제 요약 : over foot pizza breaks record for world longest
#
#
# 추상적 요약 :  world oldest floating swimming pool in world record
#
#
# 추출적 요약: pizza measuring feet set guinness world record longest pizza .
# ----------------------------------------------------------------------------------------------------
# 원문 : indian premier league council hiked salary cap ipl crore season crore last year allowed spend crore crore teams need spend least salary cap season
#
#
# 실제 요약 : salary cap for ipl teams hiked from crore to crore
#
#
# 추상적 요약 :  how much money to earn cr in ipl auction
#
#
# 추출적 요약: spend least salary cap season
# ----------------------------------------------------------------------------------------------------
# 원문 : producer kiran shroff talking comments faced said central board film certification member asked could make film like woman male member added woman look wearing kiran said thoughts
#
#
# 실제 요약 : cbfc member made sexist remark maker
#
#
# 추상적 요약 :  slams rumours of being called
#
#
# 추출적 요약: member added woman look wearing kiran said thoughts
# ----------------------------------------------------------------------------------------------------
# 원문 : stopping deliveries day due suspension rail services mumbai tuesday fed people weak affected heavy rainfall city act carried bank initiative launched last year aim fight hunger
#
#
# 실제 요약 : feed poor people affected by mumbai rains
#
#
# 추상적 요약 :  what are the of the green
#
#
# 추출적 요약: stopping deliveries day due suspension rail services mumbai tuesday .
# ----------------------------------------------------------------------------------------------------
# 원문 : rape convict ram rahim singh running based dera sacha sauda haryana jail currently lodged dera chairperson said tuesday adding plans naming refuted claims made ram rahim mother son nominated next dera chief
#
#
# 실제 요약 : ram rahim singh to run dera from jail
#
#
# 추상적 요약 :  ram rahim dera ram rahim singh
#
#
# 추출적 요약: rape convict ram rahim singh running based dera sacha .
# next dera chief
# ----------------------------------------------------------------------------------------------------
# 원문 : following chennai super kings record third title indian premier league csk captain ms dhoni said team visiting chennai meet franchise fans plans celebrate get together hotel celebrate dhoni added asked celebrations
#
#
# 실제 요약 : going to chennai to celebrate ipl title win with fans dhoni
#
#
# 추상적 요약 :  dhoni posts final with dhoni in ipl
#
#
# 추출적 요약: league csk captain ms dhoni said team visiting chennai meet .
# franchise fans plans celebrate get together hotel celebrate dhoni added .
# ----------------------------------------------------------------------------------------------------
# 원문 : woman allegedly abducted golf course metro station noida gang raped moving vehicle thrown near temple delhi friday police registered fir unidentified men sent victim medical examination woman reportedly waiting cab near station abducted
#
#
# 실제 요약 : woman abducted gang raped in moving car in noida
#
#
# 추상적 요약 :  woman gangraped by men gangraped in moving train in bihar
#
#
# 추출적 요약: woman allegedly abducted golf course metro station noida gang .
# cab near station abducted
# ----------------------------------------------------------------------------------------------------
# 원문 : delhi cm arvind kejriwal friday tweeted approved delivery proposal comes days supreme court ruled delhi government require lieutenant governor every issue act earlier aap government claimed anil baijal rejected scheme
#
#
# 실제 요약 : approved delivery kejriwal after sc verdict
#
#
# 추상적 요약 :  delhi cm kejriwal to make quota in delhi
#
#
# 추출적 요약: delhi cm arvind kejriwal friday tweeted approved delivery proposal .
# comes days supreme court ruled delhi government require lieutenant governor .
# ----------------------------------------------------------------------------------------------------
# 원문 : air india issued advisory asking cabin crew members carry uniform documents holiday report duty falls short staff destination advisory comes air india flying minimum crew members per directorate general civil aviation norms
#
#
# 실제 요약 : air india asks crew to carry uniform on holiday
#
#
# 추상적 요약 :  air india denies delay in air india crew crew
#
#
# 추출적 요약: air india issued advisory asking cabin crew members carry .
# comes air india flying minimum crew members per directorate general .
# ----------------------------------------------------------------------------------------------------
# 원문 : armed forces personnel may soon wear according reports defence ministry sent uniform along samples villages industries commission minister state defence subhash said friday requested armed forces consider using security personnel added
#
#
# 실제 요약 : armed forces may soon wear uniform
#
#
# 추상적 요약 :  terrorists to observe armed forces in mizoram
#
#
# 추출적 요약: armed forces personnel may soon wear according reports defence .
# defence subhash said friday requested armed forces consider using security .
# ----------------------------------------------------------------------------------------------------
# 원문 : startups enterprises offering shared private offices conference rooms networking opportunities help business grow first delhi ncr location launch early located right next metro station making easily
#
#
# 실제 요약 : wework to open in delhi ncr
#
#
# 추상적 요약 :  invests in bengaluru to be launched
#
#
# 추출적 요약: opportunities help business grow first delhi ncr location launch early .
# ----------------------------------------------------------------------------------------------------
# 원문 : govinda responded late actor khan son criticism wherein questioned govinda call even demise kid like comment got know said govinda criticised govinda called father figure instagram demise
#
#
# 실제 요약 : he is kid govinda on son criticism after actor death
#
#
# 추상적 요약 :  dad is my son govinda on son death
#
#
# 추출적 요약: govinda responded late actor khan son criticism wherein questioned .
# ----------------------------------------------------------------------------------------------------
# 원문 : tata motors land rover warned bad brexit deal could lead thousands job losses cost company billion year losing easy access europe single market would mean customs official becomes important engineer ceo said
#
#
# 실제 요약 : tata jaguar warns hard brexit could cost thousands of jobs
#
#
# 추상적 요약 :  tata steel could not impact steel steel steel steel
#
#
# 추출적 요약: tata motors land rover warned bad brexit deal could .
# access europe single market would mean customs official becomes important .
# ----------------------------------------------------------------------------------------------------
# 원문 : india biggest sale flipkart big billion days back september th th event finally bring solution biggest indian across flipkart set offer tonnes exclusive deals consumers days
#
#
# 실제 요약 : flipkart big billion days starts from september th
#
#
# 추상적 요약 :  india has billion in last years
#
#
# 추출적 요약: india biggest sale flipkart big billion days back september .
# ----------------------------------------------------------------------------------------------------
# 원문 : barcelona midfielder currently loan ak banned record matches pushing insulting threatening turkish league match year old sent assistant referee decision also handed lakh fine thrown direction
#
#
# 실제 요약 : bar handed record match ban for
#
#
# 추상적 요약 :  iranian footballer banned from iran for
#
#
# 추출적 요약: barcelona midfielder currently loan ak banned record matches pushing .
# ----------------------------------------------------------------------------------------------------
# 원문 : nasa discovered planet known universe surface temperature jupiter like giant nearly hot sun locked host star meaning planet one side always facing star researchers said host star even planet
#
#
# 실제 요약 : hottest ever known planet found with of
#
#
# 추상적 요약 :  nasa finds image of earth like star found in orbit
#
#
# 추출적 요약: side always facing star researchers said host star even planet .
# ----------------------------------------------------------------------------------------------------
# 원문 : cbi booked auto jharkhand allegedly loan amount causing loss crore corporation bank agency booked estate directors along bank sanjay kumar corporation bank alleged kumar filed valuation reports based loan sanctioned
#
#
# 실제 요약 : bank reports fraud of crore to cbi
#
#
# 추상적 요약 :  cbi books booked for crore fraud in bank fraud
#
#
# 추출적 요약: cbi booked auto jharkhand allegedly loan amount causing loss .
# kumar corporation bank alleged kumar filed valuation reports based loan .
# ----------------------------------------------------------------------------------------------------
# 원문 : india japan signed pact thursday start service help japanese people living india order food japan saying japan become third largest investor india pm narendra modi added food delivery service called cool box service help improve people people ties two countries
#
#
# 실제 요약 : service to order food from japan to india announced
#
#
# 추상적 요약 :  japan to build world largest branch with japan
#
#
# 추출적 요약: india japan signed pact thursday start service help japanese .
# people living india order food japan saying japan become third .
# ----------------------------------------------------------------------------------------------------
# 원문 : delhi transport minister kailash said state government may implement even vehicle scheme view increasing pollution levels wednesday wrote delhi transport corporation ministry officials asking fully implementation scheme announced
#
#
# 실제 요약 : delhi govt may implement odd even scheme again minister
#
#
# 추상적 요약 :  delhi govt to adopt odd even in odd even
#
#
# 추출적 요약: delhi transport minister kailash said state government may implement .
# ----------------------------------------------------------------------------------------------------
# 원문 : people bihar occasion bihar pm narendra modi thursday tweeted right historical times bihar contribution towards nation progress bihar observed mark formation state bihar bengal presidency british
#
#
# 실제 요약 : bihar to india pm modi
#
#
# 추상적 요약 :  modi has not in gujarat gujarat cm
#
#
# 추출적 요약: mark formation state bihar bengal presidency british
# ----------------------------------------------------------------------------------------------------
# 원문 : rajasthan high court directed makers padmaavat screen film court january response plea director sanjay leela bhansali appealed fir state fir filed march sought action bhansali deepika padukone ranveer singh
#
#
# 실제 요약 : screen padmaavat for court before jan rajasthan hc
#
#
# 추상적 요약 :  court asks baahubali to release padmaavat in raj
#
#
# 추출적 요약: january response plea director sanjay leela bhansali appealed fir state .
# ----------------------------------------------------------------------------------------------------
# 원문 : benchmark index sensex fell second consecutive session friday dragged reliance industries hdfc yes bank sensex closed points nifty index ended points lower non banking finance companies continued face selling pressure housing finance falling
#
#
# 실제 요약 : sensex falls for second straight day points
#
#
# 추상적 요약 :  sensex jumps points points to points in months
#
#
# 추출적 요약: reliance industries hdfc yes bank sensex closed points nifty index .
# ended points lower non banking finance companies continued face selling .
# ----------------------------------------------------------------------------------------------------
# 원문 : former pakistan president claimed chief hafiz saeed involved mumbai attacks left dead hafiz saeed issue issue india united states pakistan call terrorist added notably us declared international terrorist organisation
#
#
# 실제 요약 : hafiz saeed not involved in mumbai attacks musharraf
#
#
# 추상적 요약 :  mastermind hafiz saeed is mastermind hafiz saeed
#
#
# 추출적 요약: former pakistan president claimed chief hafiz saeed involved mumbai .
# ----------------------------------------------------------------------------------------------------
# 원문 : least flights major offices stock markets opened hour late students took nine hour college entrance exam south korea thursday south korean airports suspended minutes english test students stuck traffic rushed police vehicles exam centres
#
#
# 실제 요약 : flights suspended offices open late for hour exam in korea
#
#
# 추상적 요약 :  paris student who missed alcohol from us
#
#
# 추출적 요약: students took nine hour college entrance exam south korea thursday .
# south korean airports suspended minutes english test students stuck traffic .
# ----------------------------------------------------------------------------------------------------
# 원문 : pakistan opposition parties nominated former pm nawaz sharif brother sharif pm candidate comes pakistan single largest party recently held general elections nominated imran khan pm candidate pakistan claimed support members form government
#
#
# 실제 요약 : pak opp fields sharif as pm against imran
#
#
# 추상적 요약 :  pakistan pm nawaz sharif elected pm nawaz sharif
#
#
# 추출적 요약: pakistan opposition parties nominated former pm nawaz sharif brother .
# sharif pm candidate comes pakistan single largest party recently held .
# ----------------------------------------------------------------------------------------------------
# 원문 : union minister science technology harsh meet beijing china said india importance cow carrying scientific research added scientists directed come findings whether positive negative settle benefits cow milk urine
#
#
# 실제 요약 : india will use science to prove of cow
#
#
# 추상적 요약 :  india has not to fight terrorism
#
#
# 추출적 요약: india importance cow carrying scientific research added scientists directed come .
# ----------------------------------------------------------------------------------------------------
# 원문 : met organised first monday may new york every year since event opening museum art institute fashion year event celebrating specific theme met raised approximately million
#
#
# 실제 요약 : what is the annual met event
#
#
# 추상적 요약 :  st to get its first museum in the world
#
#
# 추출적 요약: met organised first monday may new york every year .
# ----------------------------------------------------------------------------------------------------
# 원문 : england men basketball team player anderson proposed girlfriend court victory commonwealth games sunday england men team gathered post game england women basketball team player watched broke anderson waiting one holding engagement ring
#
#
# 실제 요약 : basketball player proposes to girlfriend on court after game
#
#
# 추상적 요약 :  player proposes to girlfriend after st match in
#
#
# 추출적 요약: england men basketball team player anderson proposed girlfriend court .
# england women basketball team player watched broke anderson waiting one .
# ----------------------------------------------------------------------------------------------------
# 원문 : central bureau investigation move supreme court allahabad high court verdict rajesh murder case daughter domestic help cbi court convicted case sentenced life imprisonment recently wife also challenged couple
#
#
# 실제 요약 : cbi to move sc against in murder
#
#
# 추상적 요약 :  sc verdict on death case against father in murder case
#
#
# 추출적 요약: verdict rajesh murder case daughter domestic help cbi court convicted .
# ----------------------------------------------------------------------------------------------------
# 원문 : bank managing director ceo given one year extension government thursday chartered joined bank october previously ceo value homes co founded also spent years india singapore starting
#
#
# 실제 요약 : bank of ceo gets one year extension
#
#
# 추상적 요약 :  bank ceo pay for years of axis bank
#
#
# 추출적 요약: bank managing director ceo given one year extension government .
# ----------------------------------------------------------------------------------------------------
# 원문 : elon musk led startup boring company distributed first batch commercial called customers company headquarters priced remaining coming weeks earlier january musk sold million worth less hours
#
#
# 실제 요약 : musk boring company first
#
#
# 추상적 요약 :  musk boring company to sell startup for finding
#
#
# 추출적 요약: elon musk led startup boring company distributed first batch .
# ----------------------------------------------------------------------------------------------------
# 원문 : scored long range bullet strike draw liverpool premier league sunday received ball hit first time landing top left corner later liverpool went ahead time mohamed effort following harry converted penalty draw
#
#
# 실제 요약 : player scores long range bullet against liverpool in pl
#
#
# 추상적 요약 :  scores in minutes as army win st goal in seconds
#
#
# 추출적 요약: scored long range bullet strike draw liverpool premier league .
# later liverpool went ahead time mohamed effort following harry converted .
# ----------------------------------------------------------------------------------------------------
# 원문 : karnataka cm siddaramaiah tuesday called uttar pradesh cm yogi adityanath mahatma gandhi adding need learn cm siddaramaiah said adityanath raj uttar pradesh comes adityanath said working siddaramaiah allies
#
#
# 실제 요약 : yogi adityanath is karnataka cm
#
#
# 추상적 요약 :  yogi cm yogi adityanath in up
#
#
# 추출적 요약: raj uttar pradesh comes adityanath said working siddaramaiah allies
# ----------------------------------------------------------------------------------------------------
# 원문 : seeking foreign minister sushma swaraj help visa issue twitter user posted please help visa commit suicide get problem across replying woman query swaraj tweeted aap
#
#
# 실제 요약 : should kill myself over visa issue tweets user to swaraj
#
#
# 추상적 요약 :  swaraj slammed for posting tweet on rape victim
#
#
# 추출적 요약: seeking foreign minister sushma swaraj help visa issue twitter .
# ----------------------------------------------------------------------------------------------------
# 원문 : germany canada based study found life earth began within million years planet formation warm little evidence based suggest dry self constituted first genetic code life planet
#
#
# 실제 요약 : life in just after earth formation study
#
#
# 추상적 요약 :  earth found in earth found in earth
#
#
# 추출적 요약: self constituted first genetic code life planet
# ----------------------------------------------------------------------------------------------------
# 원문 : pakistan karachi claimed lives people three days according foundation non profit organisation runs city temperatures karachi reached high monday way average daily high month may situation due power
#
#
# 실제 요약 : pakistan kills people in days report
#
#
# 추상적 요약 :  pakistan records highest ever since
#
#
# 추출적 요약: non profit organisation runs city temperatures karachi reached high monday .
# ----------------------------------------------------------------------------------------------------
# 원문 : congress wednesday announced party chief spokesperson randeep singh surjewala contest january haryana mla earlier served minister congress government led ex cm singh bjp son indian national lok dal mla whose death
#
#
# 실제 요약 : cong fields as candidate for bypoll
#
#
# 추상적 요약 :  cong appoints as party in punjab
#
#
# 추출적 요약: congress wednesday announced party chief spokesperson randeep singh surjewala .
# contest january haryana mla earlier served minister congress government led .
# ----------------------------------------------------------------------------------------------------
# 원문 : police inspector allegedly group inside madras high court campus monday inspector gone court appear case assailants approached accused bad later took shelter government allegedly started abusing
#
#
# 실제 요약 : police by at madras hc
#
#
# 추상적 요약 :  cops booked for having sex with tn police
#
#
# 추출적 요약: police inspector allegedly group inside madras high court campus .
# ----------------------------------------------------------------------------------------------------
# 원문 : football team lakh world cup shirts sold within minutes made available pre order online friday long seen outside store london football team ranked th world group argentina croatia iceland upcoming edition
#
#
# 실제 요약 : nigeria wc kit sold out in min after lakh pre orders
#
#
# 추상적 요약 :  world no expensive trophy sold for lakh
#
#
# 추출적 요약: football team lakh world cup shirts sold within minutes .
# london football team ranked th world group argentina croatia iceland .
# ----------------------------------------------------------------------------------------------------
# 원문 : us court passed interim order preventing collecting debt fraud accused nirav modi firm diamond filed bankruptcy stay required pay actual damages attorney fees court said blamed supply chain challenges bankruptcy nearly billion fraud
#
#
# 실제 요약 : us court debt collection from nirav firm
#
#
# 추상적 요약 :  ed questions in nirav modi case
#
#
# 추출적 요약: us court passed interim order preventing collecting debt fraud .
# bankruptcy nearly billion fraud
# ----------------------------------------------------------------------------------------------------
# 원문 : uttar pradesh government scrapped public holiday marking death anniversary dr ambedkar ambedkar th birth anniversary april year chief minister yogi adityanath said birth great personalities cutting academic sessions special programme held teach students instead suggested
#
#
# 실제 요약 : up cancels public holiday on ambedkar death anniversary
#
#
# 추상적 요약 :  up govt to provide to death for kids
#
#
# 추출적 요약: uttar pradesh government scrapped public holiday marking death anniversary .
# dr ambedkar ambedkar th birth anniversary april year chief minister .
# ----------------------------------------------------------------------------------------------------
# 원문 : uttar pradesh deputy cm prasad said ram mandir built lord ram date construction decided congress chief rahul gandhi earlier remark structure named allowed disputed site supreme court hearing dispute
#
#
# 실제 요약 : will build ram mandir but rahul will decide date up dy cm
#
#
# 추상적 요약 :  ram temple will be built in ayodhya case cm
#
#
# 추출적 요약: uttar pradesh deputy cm prasad said ram mandir built .
# ----------------------------------------------------------------------------------------------------
# 원문 : chhattisgarh cm raman singh planning free mobile phones lakh people state within two half years communication scheme crore plan notably plan implemented two cover rural families urban poor families college youth
#
#
# 실제 요약 : chhattisgarh govt to give free mobile phones to people
#
#
# 추상적 요약 :  chhattisgarh govt to provide mobile phones to
#
#
# 추출적 요약: chhattisgarh cm raman singh planning free mobile phones lakh .
# people state within two half years communication scheme crore plan .
# ----------------------------------------------------------------------------------------------------
# 원문 : indian engineer killed hate crime us bar last year said husband american dream broken us navy veteran tuesday sentenced life prison killing husband chose address said
#
#
# 실제 요약 : my american dream is broken of indian shot at us pub
#
#
# 추상적 요약 :  us soldier killed in suicide attack on us
#
#
# 추출적 요약: life prison killing husband chose address said
# ----------------------------------------------------------------------------------------------------
# 원문 : russia claimed destroyed militant group al front largest underground ammunition tons multiple launch syria adding air strike injured terrorist group leader abu al russia said also killed field militant group denied leader injured
#
#
# 실제 요약 : destroyed al largest underground arms russia
#
#
# 추상적 요약 :  russia claims syrian chemical attack in syria
#
#
# 추출적 요약: group leader abu al russia said also killed field militant .
# group denied leader injured
# ----------------------------------------------------------------------------------------------------
# 원문 : cricket australia monday named champions trophy best xi feature single australian player australian pacer tournament second highest wicket also could make list eight players asia included best xi pakistani skipper ahmed named captain side
#
#
# 실제 요약 : no australian in cricket australia ct best xi
#
#
# 추상적 요약 :  india top captain to play int cricket in australia
#
#
# 추출적 요약: cricket australia monday named champions trophy best xi feature .
# could make list eight players asia included best xi pakistani .
# ----------------------------------------------------------------------------------------------------
# 원문 : royal house mumbai opening quarter venue comprising bar restaurant bar quarter designed also worked recent house house presently owned former royal family first inaugurated
#
#
# 실제 요약 : mumbai royal house opening bar and restaurant
#
#
# 추상적 요약 :  mumbai house tower costliest guests to guests
#
#
# 추출적 요약: royal house mumbai opening quarter venue comprising bar restaurant .
# ----------------------------------------------------------------------------------------------------
# 원문 : day inauguration delhi signature bridge aam aadmi party official twitter account tweeted three images claiming signature bridge however one pictures bridge located netherlands pointing error bjp spokesperson tweeted vikas photo ki na
#
#
# 실제 요약 : aap posts pic of netherlands bridge as delhi bridge
#
#
# 추상적 요약 :  goa cm tweets user on twitter after tamil nadu
#
#
# 추출적 요약: day inauguration delhi signature bridge aam aadmi party official .
# twitter account tweeted three images claiming signature bridge however one .
# ----------------------------------------------------------------------------------------------------
# 원문 : three students committed suicide delhi cbse class board results declared tuesday year old girl scored committed suicide academic performance wished join science police said deceased also included student scored another
#
#
# 실제 요약 : delhi students commit suicide after cbse class results
#
#
# 추상적 요약 :  class students allegedly killed in class exam
#
#
# 추출적 요약: three students committed suicide delhi cbse class board results .
# ----------------------------------------------------------------------------------------------------
# 원문 : speaking welfare animals actor randeep said animals try voice animals especially wild animals share connection humans times randeep added actor said important treat animals
#
#
# 실제 요약 : try to be voice for animals
#
#
# 추상적 요약 :  there is not eat your weapons in
#
#
# 추출적 요약: speaking welfare animals actor randeep said animals try voice .
# ----------------------------------------------------------------------------------------------------
# 원문 : government proposed create special group keep check commerce platforms like flipkart amazon india foreign investment policy violated officials industry department enforcement directorate group temporary solution government national policy commerce sector india
#
#
# 실제 요약 : govt proposes special group to keep firms in check
#
#
# 추상적 요약 :  govt to hire flipkart for startups
#
#
# 추출적 요약: government proposed create special group keep check commerce platforms .
# department enforcement directorate group temporary solution government national policy commerce .
# ----------------------------------------------------------------------------------------------------
# 원문 : constable shot neck duty former tamil nadu chief minister jayalalithaa memorial chennai sunday according reports hearing sound constable colleagues investigated found dead reports said whether suicide accidental shooting
#
#
# 실제 요약 : constable jayalalithaa memorial shoots himself
#
#
# 추상적 요약 :  man shoots tn jayalalithaa jayalalithaa at jayalalithaa house
#
#
# 추출적 요약: jayalalithaa memorial chennai sunday according reports hearing sound constable colleagues .
# ----------------------------------------------------------------------------------------------------
# 원문 : national company law tribunal stayed order competition commission india imposed penalty crore google search tribunal also directed google deposit penalty amount february commission said google abusing online web search online search advertising markets
#
#
# 실제 요약 : stays cr penalty on google in search bias case
#
#
# 추상적 요약 :  google fined crore for misleading google
#
#
# 추출적 요약: imposed penalty crore google search tribunal also directed google deposit .
# penalty amount february commission said google abusing online web search .
# ----------------------------------------------------------------------------------------------------
# 원문 : former adam found guilty public funds spend game war mobile game according police used funds purchase amazon google play gift cards converted virtual coins sentenced days jail
#
#
# 실제 요약 : steals over lakh to spend on mobile game
#
#
# 추상적 요약 :  ex adult jailed for selling in
#
#
# 추출적 요약: former adam found guilty public funds spend game war .
# ----------------------------------------------------------------------------------------------------
# 원문 : two youths arrested thursday allegedly mentally challenged class student west bengal according complaint registered victim father accused girl promise took abandoned building assaulted medical test victim conducted police said
#
#
# 실제 요약 : mentally challenged minor girl gangraped in wb two arrested
#
#
# 추상적 요약 :  class boy arrested for sexually assaulting minor
#
#
# 추출적 요약: west bengal according complaint registered victim father accused girl promise .
# ----------------------------------------------------------------------------------------------------
# 원문 : reacting indian record asian games medal tally indian cricketer gautam gambhir said many heroes compared create cricket india actual heroes always cricketers put cricket popular sport country gambhir said
#
#
# 실제 요약 : asiad winners are the heroes gambhir
#
#
# 추상적 요약 :  indian team has not indian to win indian team
#
#
# 추출적 요약: heroes always cricketers put cricket popular sport country gambhir said .
# ----------------------------------------------------------------------------------------------------
# 원문 : committee gujarat secondary higher secondary education board banned class boy taking exams two years taking selfie examination hall cctv footage incident confirm use phone cheat exam declared failed papers
#
#
# 실제 요약 : boy barred from taking tests for taking selfie in exam hall
#
#
# 추상적 요약 :  class student exam exam fails to answer exam
#
#
# 추출적 요약: boy taking exams two years taking selfie examination hall cctv .
# ----------------------------------------------------------------------------------------------------
# 원문 : akshay kumar requested people donate families via government bharat ke initiative event later said within minutes raised close crore akshay added able ensure listed website would get target amount help
#
#
# 실제 요약 : within minutes raised cr for families of martyrs akshay
#
#
# 추상적 요약 :  akshay to donate lakh for mumbai metro donation
#
#
# 추출적 요약: akshay kumar requested people donate families via government bharat .
# akshay added able ensure listed website would get target amount .
# ----------------------------------------------------------------------------------------------------
# 원문 : china deployed class diesel electric submarine indian ocean region seventh submarine deployed region according indian navy chinese region appeared moreover also spy ship deployed electronic signals returned beijing analysis
#
#
# 실제 요약 : china submarine in indian ocean amid standoff
#
#
# 추상적 요약 :  china china tests st ever naval naval drill
#
#
# 추출적 요약: china deployed class diesel electric submarine indian ocean region .
# ----------------------------------------------------------------------------------------------------
# 원문 : prime minister narendra modi monday met group women motorcycle riders gujarat new delhi pm modi group efforts promote like swachh bharat group said km covering states union territories promote social
#
#
# 실제 요약 : pm narendra modi meets from gujarat
#
#
# 추상적 요약 :  pm modi meets metro in delhi
#
#
# 추출적 요약: riders gujarat new delhi pm modi group efforts promote like .
# swachh bharat group said km covering states union territories promote .
# ----------------------------------------------------------------------------------------------------
# 원문 : reacting indian team coach ravi shastri late tweet captain virat kohli post marriage anushka sharma user wrote ab users wrote singing media like ravi shastri nahi di kya hai
#
#
# 실제 요약 : ab tweets user on shastri late wish to kohli
#
#
# 추상적 요약 :  ravi shastri tweets user on virat kohli
#
#
# 추출적 요약: wrote singing media like ravi shastri nahi di kya hai .
# ----------------------------------------------------------------------------------------------------
# 원문 : us president donald trump offered build wall crime fall new party theme referring demands build wall along us mexico border bid curb illegal migration crime us government partially shut month trump demands funds build wall
#
#
# 실제 요약 : build wall crime will fall trump new party
#
#
# 추상적 요약 :  trump signs plan to mexico border wall wall
#
#
# 추출적 요약: us president donald trump offered build wall crime fall .
# month trump demands funds build wall
# ----------------------------------------------------------------------------------------------------
# 원문 : congress leader shashi tharoor monday tweeted poem media accepted friend challenge find word word encouraging interest sexual matters especially sexual activity others last year tharoor tweet went viral social media
#
#
# 실제 요약 : tharoor accepts friend challenge finds for
#
#
# 추상적 요약 :  tharoor trolled for posting tweet on sex abuse
#
#
# 추출적 요약: congress leader shashi tharoor monday tweeted poem media accepted .
# sexual activity others last year tharoor tweet went viral social .
# ----------------------------------------------------------------------------------------------------
# 원문 : roll gst indian wedding union minister jayant sinha wednesday said like indian great big party everyone live ever sinha said call gst republic adding tax would help control inflation people india
#
#
# 실제 요약 : sinha gst launch to happy indian wedding
#
#
# 추상적 요약 :  gst is not sure on gst on india gst
#
#
# 추출적 요약: roll gst indian wedding union minister jayant sinha wednesday .
# said like indian great big party everyone live ever sinha .
# ----------------------------------------------------------------------------------------------------
# 원문 : billionaire bill gates monday met us president donald trump white house discuss trump budget proposal would impose cuts foreign aid comes trump claimed budget would security well americans gates responded article arguing providing overseas aid helps keep americans safe
#
#
# 실제 요약 : bill gates meets donald trump to discuss cut in foreign aid
#
#
# 추상적 요약 :  billionaire praises trump trump to trump
#
#
# 추출적 요약: billionaire bill gates monday met us president donald trump .
# aid comes trump claimed budget would security well americans gates .
# ----------------------------------------------------------------------------------------------------
# 원문 : man teaching school west bengal arrested sunday allegedly molesting three girl students aged nine years showing last three years accused would force children remove clothes touch victim parent claimed sent judicial custody
#
#
# ...
#
#
# 실제 요약 : first poem wrote was for my late mother sushant
#
#
# 추상적 요약 :  sushant shares pic with her daughter in his th year
#
#
# 추출적 요약: sushant singh rajput revealed poem wrote mother passed away .
# ----------------------------------------------------------------------------------------------------
# 원문 : following demise former prime minister atal bihari vajpayee thursday west bengal cm mamata banerjee tweeted great former pm shri atal bihari vajpayee ji us passing away big loss nation always many added
#
#
# 실제 요약 : vajpayee passing away very big loss to our nation mamata
#
#
# 추상적 요약 :  vajpayee was late pm vajpayee niece
#
#
# 추출적 요약: following demise former prime minister atal bihari vajpayee thursday .
# atal bihari vajpayee ji us passing away big loss nation .
# ----------------------------------------------------------------------------------------------------
# 원문 : australia based researchers software signs measuring writing speed pen pressure person person trial detected disease involving researchers hope tool could one day used standard screening test spot condition earliest stages
#
#
# 실제 요약 : test detects signs of
#
#
# 추상적 요약 :  scientists discover human dna in human eye
#
#
# 추출적 요약: australia based researchers software signs measuring writing speed pen .
# pressure person person trial detected disease involving researchers hope tool .
# ----------------------------------------------------------------------------------------------------
# 원문 : army received first batch modern bullet proof two decades process ballistic impact ammunition fired short range meeting global standard protection among leading armed forces provide round protection head injuries opposed previous ones protected back
#
#
# 실제 요약 : army gets modern bullet proof after year wait
#
#
# 추상적 요약 :  army army to army for st time in south africa
#
#
# 추출적 요약: protection among leading armed forces provide round protection head injuries .
# opposed previous ones protected back
# ----------------------------------------------------------------------------------------------------
# 원문 : late goal spanish forward thursday helped real madrid end three match run struck th minute first leg earlier competition messi missed penalty kick barcelona loss
#
#
# 실제 요약 : th minute goal ends real madrid run
#
#
# 추상적 요약 :  chelsea score in minutes after scoring
#
#
# 추출적 요약: late goal spanish forward thursday helped real madrid end .
# ----------------------------------------------------------------------------------------------------
# 원문 : mahindra group chairman anand mahindra tweeted video man bike multiple field using belt type system called mahindra called exercise twitter users suggested innovation called bike metro
#
#
# 실제 요약 : anand mahindra shares video of
#
#
# 추상적 요약 :  anand mahindra shares video of man who got him
#
#
# 추출적 요약: twitter users suggested innovation called bike metro
# ----------------------------------------------------------------------------------------------------
# 원문 : recent long mission nasa captured images group electric blue clouds made ice blue white clouds form earth regions data clouds may help scientists understand atmosphere nasa said
#
#
# 실제 요약 : nasa balloon mission captures images of electric blue
#
#
# 추상적 요약 :  nasa captures image of space telescope
#
#
# 추출적 요약: clouds may help scientists understand atmosphere nasa said
# ----------------------------------------------------------------------------------------------------
# 원문 : coach mumbai express found running without support sunday afternoon train halted near guard heard noise coming alerted officials awarded central railway possible accident
#
#
# 실제 요약 : mumbai express runs with missing wheel parts
#
#
# 추상적 요약 :  train coaches in mumbai express
#
#
# 추출적 요약: coach mumbai express found running without support sunday afternoon .
# ----------------------------------------------------------------------------------------------------
# 원문 : android andy startup essential products acquired indian origin mail management startup undisclosed amount comes shut based premium email service september always companies great technology talent help product essential products said
#
#
# 실제 요약 : android co founder startup buys india
#
#
# 추상적 요약 :  android acquires startup
#
#
# 추출적 요약: android andy startup essential products acquired indian origin mail .
# september always companies great technology talent help product essential products .
# ----------------------------------------------------------------------------------------------------
# 원문 : four engineers bengaluru built device blind easy access internet device online real time reads user unique feature device allows users text speed engineers said
#
#
# 실제 요약 : luru engineers make device for blind to access internet
#
#
# 추상적 요약 :  unveils smart that can charge
#
#
# 추출적 요약: users text speed engineers said
# ----------------------------------------------------------------------------------------------------
# 원문 : starting october pnb customers charged per transaction beyond limit five times month even pnb makes transaction pnb atm charges apply cash withdrawal mini statement currently pnb account holders make number transactions month pnb atms without charge
#
#
# 실제 요약 : pnb customers to pay charges after free atm transactions
#
#
# 추상적 요약 :  pnb to hire new banking companies to
#
#
# 추출적 요약: five times month even pnb makes transaction pnb atm charges .
# number transactions month pnb atms without charge
# ----------------------------------------------------------------------------------------------------
# 원문 : billionaire co founder bloomberg michael bloomberg urged world leaders us president donald trump stand climate change interview expressed support paris climate change agreement us pledged reduce gas emissions notably pact one trump election campaign promises
#
#
# 실제 요약 : trump on climate change michael to leaders
#
#
# 추상적 요약 :  trump moon will paris climate change branson
#
#
# 추출적 요약: us president donald trump stand climate change interview expressed support .
# paris climate change agreement us pledged reduce gas emissions notably .
# ----------------------------------------------------------------------------------------------------
# 원문 : filmmaker imtiaz ali said ranbir kapoor biggest disaster imtiaz incident ranbir liked delhi girl asked introduced imtiaz said went talk something else nervous kept trying pull back
#
#
# 실제 요약 : ranbir is the biggest disaster as says imtiaz ali
#
#
# 추상적 요약 :  ranbir kapoor is the most girl in sanju imtiaz
#
#
# 추출적 요약: filmmaker imtiaz ali said ranbir kapoor biggest disaster imtiaz .
# ----------------------------------------------------------------------------------------------------
# 원문 : scientists planning build three times bigger km long large world largest powerful future circular would generate equivalent million lightning strikes researchers said planning begin functioning billion facility took years complete
#
#
# 실제 요약 : scientists planning three times bigger than
#
#
# 추상적 요약 :  solar wind power power to land land in
#
#
# 추출적 요약: scientists planning build three times bigger km long large .
# strikes researchers said planning begin functioning billion facility took years .
# ----------------------------------------------------------------------------------------------------
# 원문 : argentine legend offered pay nearly lakh reward anyone identify person behind spreading rumours death argentina victory nigeria world cup stadium fell ill match rumours death spread social media
#
#
# 실제 요약 : maradona offers on info on person who spread death hoax
#
#
# 추상적 요약 :  player pays lakh lakh reward for fan who wanted to pay
#
#
# 추출적 요약: person behind spreading rumours death argentina victory nigeria world cup .
# ----------------------------------------------------------------------------------------------------
# 원문 : amid water himachal pradesh high court ordered water connections hotels paid water bills municipal commissioner rohit also informed court legal service authority volunteers four monitor water distribution
#
#
# 실제 요약 : cut water of hotels in shimla high court
#
#
# 추상적 요약 :  shimla water water to be shut in maharashtra
#
#
# 추출적 요약: hotels paid water bills municipal commissioner rohit also informed court .
# ----------------------------------------------------------------------------------------------------
# 원문 : new zealand current world champions four world cup men men women women notably men women teams world cup title second consecutive time women team beating france final
#
#
# 실제 요약 : nz now current world champions in four wc
#
#
# 추상적 요약 :  germany women world st women women women in wc
#
#
# 추출적 요약: men women women notably men women teams world cup title .
# ----------------------------------------------------------------------------------------------------
# 원문 : filmmakers rai anurag kashyap released audio based teaser upcoming film scheduled release november rai co produce film along films kashyap direct film revolves around story boxer uttar pradesh falls love girl
#
#
# 실제 요약 : kashyap rai to release on november
#
#
# 추상적 요약 :  kashyap to star in tamil film on report
#
#
# 추출적 요약: filmmakers rai anurag kashyap released audio based teaser upcoming .
# film scheduled release november rai co produce film along films .
# ----------------------------------------------------------------------------------------------------
# 원문 : days year old woman allegedly gangraped beach bjp leader sawant said government cannot provide security every individual sawant said need change people increase number rape cases reported police women reporting crimes added
#
#
# 실제 요약 : govt cannot give everyone security bjp leader on beach rape
#
#
# 추상적 요약 :  bjp constable raped by bjp leader in wb
#
#
# 추출적 요약: need change people increase number rape cases reported police women .
# reporting crimes added
# ----------------------------------------------------------------------------------------------------
# 원문 : former prime minister manmohan singh awarded indira gandhi prize peace development year ten years tenure singh received honour improving india world contributions cause economic social development indira gandhi memorial trust statement said
#
#
# 실제 요약 : ex pm manmohan singh awarded indira gandhi peace prize
#
#
# 추상적 요약 :  former pm manmohan singh named in world first time
#
#
# 추출적 요약: former prime minister manmohan singh awarded indira gandhi prize .
# india world contributions cause economic social development indira gandhi memorial .
# ----------------------------------------------------------------------------------------------------
# 원문 : us president donald trump called north korean leader kim jong un strong head said wants people sit attention like north leader trump hailed efforts towards improving us ties north korea claimed good relationship kim jong un
#
#
# 실제 요약 : want my people to sit up at attention when speak trump
#
#
# 추상적 요약 :  kim jong un will be in korea
#
#
# 추출적 요약: us president donald trump called north korean leader kim .
# north leader trump hailed efforts towards improving us ties north .
# ----------------------------------------------------------------------------------------------------
# 원문 : hundreds people protested mcdonald restaurants across us saturday food chain ran long production promised sell part us tv show police called least one people began getting angry want
#
#
# 실제 요약 : hundreds protest after mcdonald runs out of
#
#
# 추상적 요약 :  thousands of thousands of stores in us
#
#
# 추출적 요약: hundreds people protested mcdonald restaurants across us saturday food .
# ----------------------------------------------------------------------------------------------------
# 원문 : man claiming brother law created stopped traffic violation madhya pradesh cm shivraj singh chouhan said law take course chouhan added sisters state brother law many people video man arguing police surfaced
#
#
# 실제 요약 : law will take its course mp cm on traffic breach by kin
#
#
# 추상적 요약 :  mp cm calls for not speaking to cm
#
#
# 추출적 요약: man claiming brother law created stopped traffic violation madhya .
# added sisters state brother law many people video man arguing .
# ----------------------------------------------------------------------------------------------------
# 원문 : paying tribute nobel prize winning author vs writer salman tweeted lives politics feel sad lost older brother one first winners british award prize passed away saturday aged
#
#
# 실제 요약 : feel sad as if lost brother on death
#
#
# 추상적 요약 :  oscar winning author apologises for nobel
#
#
# 추출적 요약: paying tribute nobel prize winning author vs writer salman .
# ----------------------------------------------------------------------------------------------------
# 원문 : philippine president rodrigo duterte called north korean leader kim jong un idol time bad boy community appears good fellow hero everybody duterte said last year duterte called north korean leader son
#
#
# 실제 요약 : philippine president duterte calls kim jong un his idol
#
#
# 추상적 요약 :  kim jong un president is very dictator philippine prez
#
#
# 추출적 요약: philippine president rodrigo duterte called north korean leader kim .
# hero everybody duterte said last year duterte called north korean .
# ----------------------------------------------------------------------------------------------------
# 원문 : sunrisers hyderabad pacer bhuvneshwar kumar played five ipl matches season reportedly handed rest request bcci avoid year old earlier revealed injured measure bhuvneshwar ended last year ipl highest wicket
#
#
# 실제 요약 : bcci srh to give rest to bhuvneshwar report
#
#
# 추상적 요약 :  bhuvneshwar kumar to get ipl for ipl
#
#
# 추출적 요약: revealed injured measure bhuvneshwar ended last year ipl highest wicket .
# ----------------------------------------------------------------------------------------------------
# 원문 : new york times warned us president donald trump continue reporters people meeting earlier month told trump remark could lead violence media revealed details record meeting trump tweeted
#
#
# 실제 요약 : stop as to trump
#
#
# 추상적 요약 :  trump slams trump over hate hate speech
#
#
# 추출적 요약: violence media revealed details record meeting trump tweeted
# ----------------------------------------------------------------------------------------------------
# 원문 : confirming reports meeting us central intelligence agency chief mike pompeo north korean leader kim jong un us president donald trump wednesday said two formed good relationship trump added us north korea working details bilateral summit expected held june year
#
#
# 실제 요약 : cia chief formed good relationship with kim jong un trump
#
#
# 추상적 요약 :  trump kim jong un is very trump
#
#
# 추출적 요약: pompeo north korean leader kim jong un us president donald .
# north korea working details bilateral summit expected held june year .
# ----------------------------------------------------------------------------------------------------
# 원문 : defence minister nirmala sitharaman alleged congress leader abhishek wife director private firm company owned jeweller nirav modi accused crore fraud allegations abhishek said resort legal action minister making false allegations
#
#
# 실제 요약 : cong leader wife was with nirav firm sitharaman
#
#
# 추상적 요약 :  sitharaman accuses nirav modi of nirav modi
#
#
# 추출적 요약: defence minister nirmala sitharaman alleged congress leader abhishek wife .
# fraud allegations abhishek said resort legal action minister making false .
# ----------------------------------------------------------------------------------------------------
# 원문 : reacting congress demand government disclose price rafale fighter jets finance minister arun jaitley said issue adding nda government clean government jaitley said congress manufacturing allegations corruption congress national security asking details deal added
#
#
# 실제 요약 : congress manufacturing issue by asking rafale deal price fm
#
#
# 추상적 요약 :  rafale deal is rafale deal arun jaitley
#
#
# 추출적 요약: finance minister arun jaitley said issue adding nda government clean .
# government jaitley said congress manufacturing allegations corruption congress national security .
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# 문법 완성도 측면에서는 추출적 요약보다 추상적 요약이 좀 더 깔끔하다. 아무래도 추출적 요약은 원문에서 있는 단어 들만 뽑아 오다 보니 요약적인 측면에서는 추상적 요약이 더 월등하다고 판단한다.
#
# 핵심단어 포함 측면에서는 추출적 요약이 추상적 요약 보다 더 잘 포함 된것 같다. 추출적 요약이 원문에 있는 단어로 만들기 때문이라고 판단한다.

# %% [markdown]
# # 회고
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 이번 프로젝트에서 **어려웠던 점,**
#     - 긴 모델 훈련 시간.
#
# - 프로젝트를 진행하면서 **알아낸 점** 혹은 **아직 모호한 점**.
#     - 추출적, 추상적 요약에 대한 개념
#     - seq2seq 모델에 대한 개념이 모호하다.
#
# - 루브릭 평가 지표를 맞추기 위해 **시도한 것들**.
#     - 추출적, 추상적 요약에 대한 개념 자료 조사
#
# - **자기 다짐**
#     - RNN 아키텍쳐에 대한 개념을 복습하도록하자.
